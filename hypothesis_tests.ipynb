# %%
import numpy as np
import pickle
import pandas as pd
from scipy.ndimage import gaussian_filter1d
from scipy import stats

# %% [markdown]
# # Significance testing

# %% [markdown]
# ## Clusterin Coefficient

# %%
## collating clustering coeff data in dataframe form
df_dict = {}
for network in ['SF','SW','ER']:
    df_dict[network] = {}
    if network == 'ER':
        avg_clust_dict = {'net':[],'RW':[],'MHRW':[]}
        global_clust_dict = {'net':[],'RW':[],'MHRW':[]}
        for network_idx in ['ER_1','ER_2','ER_3']:
        # network = 'ER_1'
            tmp_dict1  = pickle.load(open(f"/home/neha/results/{network_idx}_avg_clust_coeff.pkl","rb"))
            tmp_dict2  = pickle.load(open(f"/home/neha/results/{network_idx}_global_clust_coeff.pkl","rb"))
            for key in avg_clust_dict.keys():
                avg_clust_dict[key].extend(tmp_dict1[key])
                global_clust_dict[key].extend(tmp_dict2[key])
            # break
    else :
        avg_clust_dict = pickle.load(open(f"/home/neha/results/{network}_combined_avg_clust_coeff.pkl","rb"))
        global_clust_dict = pickle.load(open(f"/home/neha/results/{network}_combined_global_clust_coeff.pkl","rb"))

    dict_of_dict = {'avg':avg_clust_dict,'global':global_clust_dict}
    for key,value in dict_of_dict.items():
        avg_dict= {}
        avg_dict['OG'] = value['net']
        for algo in ['RW','MHRW']:
            ls_avg = [np.mean(value[algo][i:i+100]) for i in range(0,len(value[algo]),100)]
            avg_dict[algo] = ls_avg

        df = pd.DataFrame([(key, value) for key, values in avg_dict.items() for value in values], columns=['Network', 'Value'])
        df_dict[network][key] = df

# %% [markdown]
# #### Normality test
# - Sample size >1000, so using Kolmorgorov-Smirnov Test
# - Compares data to normal distribution. H0 is of normal distribution.
#     - If p < 0.05 then not-normally distributed
#     - If p > 0.05 then normally distributed

# %%
## normality test - H0: distribution it normal 
### not normal
normality_test_df = []
for key,value in df_dict.items():
    for clust,df in value.items(): 
        for network in ['OG','RW','MHRW']:
            test_stat = stats.ks_1samp(df[df['Network']==network]['Value'],stats.norm.cdf)
            normality_test_df.append([key, clust,network,test_stat.pvalue, test_stat.statistic])

normality_test_df = pd.DataFrame(normality_test_df,columns =['network','clust_coeff','algo','p_value','ks_stats'])           
normality_test_df['Hypothesis'] = normality_test_df['p_value'].apply(lambda x : 'Normal' if x >0.05 else 'Not Normal')

# %%
normality_test_df
# Out:
#    network clust_coeff  algo  p_value  ks_stats  Hypothesis
# 0       SF         avg    OG      0.0  0.500000  Not Normal
# 1       SF         avg    RW      0.0  0.500000  Not Normal
# 2       SF         avg  MHRW      0.0  0.500000  Not Normal
# 3       SF      global    OG      0.0  0.500000  Not Normal
# 4       SF      global    RW      0.0  0.500000  Not Normal
# 5       SF      global  MHRW      0.0  0.500000  Not Normal
# 6       SW         avg    OG      0.0  0.523693  Not Normal
# 7       SW         avg    RW      0.0  0.525062  Not Normal
# 8       SW         avg  MHRW      0.0  0.524628  Not Normal
# 9       SW      global    OG      0.0  0.519612  Not Normal
# 10      SW      global    RW      0.0  0.535431  Not Normal
# 11      SW      global  MHRW      0.0  0.535645  Not Normal
# 12      ER         avg    OG      0.0  0.500049  Not Normal
# 13      ER         avg    RW      0.0  0.500026  Not Normal
# 14      ER         avg  MHRW      0.0  0.500011  Not Normal
# 15      ER      global    OG      0.0  0.500066  Not Normal
# 16      ER      global    RW      0.0  0.500044  Not Normal
# 17      ER      global  MHRW      0.0  0.500027  Not Normal

# %% [markdown]
# ### Two-tailed, distribution similarity test
# - H0 - distribution of two samples are same
# - H1 - distribution of two samples are not differ
# - Conclusion : p<0.05, reject null hypothesis

# %%
two_tail_clust_test_df = []
for key,value in df_dict.items():
    for clust,df in value.items(): 
        for algo1 in ['OG','RW','MHRW']:
            for algo2 in ['OG','RW','MHRW']:
                if algo1 != algo2:
                    U1, p = stats.mannwhitneyu(df[df['Network']==algo1]['Value'], df[df['Network']==algo2]['Value'], method="asymptotic") ## two-sided
                    # print(algo1,algo2, U1, p)
                    two_tail_clust_test_df.append([key,clust,algo1,algo2, U1, p])
two_tail_clust_test_df = pd.DataFrame(two_tail_clust_test_df,columns = ['network','clust_coeff','algo1','algo2','manwhit_stats','p_value'])
two_tail_clust_test_df['Hypothesis'] = two_tail_clust_test_df['p_value'].apply(lambda x : 'same distribution' if x >0.05 else 'different distribution')

# %%
two_tail_clust_test_df
# Out:
#    network clust_coeff algo1 algo2  manwhit_stats        p_value  \
# 0       SF         avg    OG    RW     33924014.5   0.000000e+00
# 1       SF         avg    OG  MHRW     72422012.5   0.000000e+00
# 2       SF         avg    RW    OG     66075985.5   0.000000e+00
# 3       SF         avg    RW  MHRW     76361113.5   0.000000e+00
# 4       SF         avg  MHRW    OG     27577987.5   0.000000e+00
# 5       SF         avg  MHRW    RW     23638886.5   0.000000e+00
# 6       SF      global    OG    RW     56741453.0   6.549693e-62
# 7       SF      global    OG  MHRW     75654084.0   0.000000e+00
# 8       SF      global    RW    OG     43258547.0   6.549693e-62
# 9       SF      global    RW  MHRW     73289097.5   0.000000e+00
# 10      SF      global  MHRW    OG     24345916.0   0.000000e+00
# 11      SF      global  MHRW    RW     26710902.5   0.000000e+00
# 12      SW         avg    OG    RW      8798885.0   0.000000e+00
# 13      SW         avg    OG  MHRW     14582755.0   0.000000e+00
# 14      SW         avg    RW    OG     91201115.0   0.000000e+00
# 15      SW         avg    RW  MHRW     58782621.0  1.191735e-102
# 16      SW         avg  MHRW    OG     85417245.0   0.000000e+00
# 17      SW         avg  MHRW    RW     41217379.0  1.191735e-102
# 18      SW      global    OG    RW            0.0   0.000000e+00
# 19      SW      global    OG  MHRW            0.0   0.000000e+00
# 20      SW      global    RW    OG    100000000.0   0.000000e+00
# 21      SW      global    RW  MHRW     41887184.0   7.145100e-88
# 22      SW      global  MHRW    OG    100000000.0   0.000000e+00
# 23      SW      global  MHRW    RW     58112816.0   7.145100e-88
# 24      ER         avg    OG    RW     17636979.0   0.000000e+00
# 25      ER         avg    OG  MHRW     33619856.0   0.000000e+00
# 26      ER         avg    RW    OG     82363021.0   0.000000e+00
# 27      ER         avg    RW  MHRW     65597286.0   0.000000e+00
# 28      ER         avg  MHRW    OG     66380144.0   0.000000e+00
# 29      ER         avg  MHRW    RW     34402714.0   0.000000e+00
# 30      ER      global    OG    RW      4155023.0   0.000000e+00
# 31      ER      global    OG  MHRW     11315215.0   0.000000e+00
# 32      ER      global    RW    OG     95844977.0   0.000000e+00
# 33      ER      global    RW  MHRW     63049999.0  3.339469e-224
# 34      ER      global  MHRW    OG     88684785.0   0.000000e+00
# 35      ER      global  MHRW    RW     36950001.0  3.339469e-224
#
#                 Hypothesis
# 0   different distribution
# 1   different distribution
# 2   different distribution
# 3   different distribution
# 4   different distribution
# 5   different distribution
# 6   different distribution
# 7   different distribution
# 8   different distribution
# 9   different distribution
# 10  different distribution
# 11  different distribution
# 12  different distribution
# 13  different distribution
# 14  different distribution
# 15  different distribution
# 16  different distribution
# 17  different distribution
# 18  different distribution
# 19  different distribution
# 20  different distribution
# 21  different distribution
# 22  different distribution
# 23  different distribution
# 24  different distribution
# 25  different distribution
# 26  different distribution
# 27  different distribution
# 28  different distribution
# 29  different distribution
# 30  different distribution
# 31  different distribution
# 32  different distribution
# 33  different distribution
# 34  different distribution
# 35  different distribution

# %% [markdown]
# ### One-tailed, distribution similarity test
# - H0 - distribution of two samples are same
# - H1 - distribution of sample1 is stochastically greater than sample2
# - Conclusion : p<0.05, reject null hypothesis

# %%
one_tail_clust_test_df = []
for key,value in df_dict.items():
    for clust,df in value.items(): 
        for algo1 in ['OG','RW','MHRW']:
            for algo2 in ['OG','RW','MHRW']:
                if algo1 != algo2:
                    U1, p = stats.mannwhitneyu(df[df['Network']==algo1]['Value'], df[df['Network']==algo2]['Value']
                                               , method="asymptotic", alternative = 'less') 
                    # print(algo1,algo2, U1, p)
                    one_tail_clust_test_df.append([key,clust,algo1,algo2, U1, p])
one_tail_clust_test_df = pd.DataFrame(one_tail_clust_test_df,columns = ['network','clust_coeff','algo1','algo2','manwhit_stats','p_value'])
one_tail_clust_test_df['Hypothesis'] = one_tail_clust_test_df['p_value'].apply(lambda x : 'same distribution' if x >0.05 else 'algo1>alog2')

# %%
one_tail_clust_test_df[one_tail_clust_test_df['Hypothesis'] == 'algo1>alog2']
# Out:
#    network clust_coeff algo1 algo2  manwhit_stats        p_value   Hypothesis
# 0       SF         avg    OG    RW     33924014.5   0.000000e+00  algo1>alog2
# 4       SF         avg  MHRW    OG     27577987.5   0.000000e+00  algo1>alog2
# 5       SF         avg  MHRW    RW     23638886.5   0.000000e+00  algo1>alog2
# 8       SF      global    RW    OG     43258547.0   3.274846e-62  algo1>alog2
# 10      SF      global  MHRW    OG     24345916.0   0.000000e+00  algo1>alog2
# 11      SF      global  MHRW    RW     26710902.5   0.000000e+00  algo1>alog2
# 12      SW         avg    OG    RW      8798885.0   0.000000e+00  algo1>alog2
# 13      SW         avg    OG  MHRW     14582755.0   0.000000e+00  algo1>alog2
# 17      SW         avg  MHRW    RW     41217379.0  5.958676e-103  algo1>alog2
# 18      SW      global    OG    RW            0.0   0.000000e+00  algo1>alog2
# 19      SW      global    OG  MHRW            0.0   0.000000e+00  algo1>alog2
# 21      SW      global    RW  MHRW     41887184.0   3.572550e-88  algo1>alog2
# 24      ER         avg    OG    RW     17636979.0   0.000000e+00  algo1>alog2
# 25      ER         avg    OG  MHRW     33619856.0   0.000000e+00  algo1>alog2
# 29      ER         avg  MHRW    RW     34402714.0   0.000000e+00  algo1>alog2
# 30      ER      global    OG    RW      4155023.0   0.000000e+00  algo1>alog2
# 31      ER      global    OG  MHRW     11315215.0   0.000000e+00  algo1>alog2
# 35      ER      global  MHRW    RW     36950001.0  1.669735e-224  algo1>alog2

# %%
one_tail_clust_test_df
# Out:
#    network clust_coeff algo1 algo2  manwhit_stats        p_value  \
# 0       SF         avg    OG    RW     33924014.5   0.000000e+00
# 1       SF         avg    OG  MHRW     72422012.5   1.000000e+00
# 2       SF         avg    RW    OG     66075985.5   1.000000e+00
# 3       SF         avg    RW  MHRW     76361113.5   1.000000e+00
# 4       SF         avg  MHRW    OG     27577987.5   0.000000e+00
# 5       SF         avg  MHRW    RW     23638886.5   0.000000e+00
# 6       SF      global    OG    RW     56741453.0   1.000000e+00
# 7       SF      global    OG  MHRW     75654084.0   1.000000e+00
# 8       SF      global    RW    OG     43258547.0   3.274846e-62
# 9       SF      global    RW  MHRW     73289097.5   1.000000e+00
# 10      SF      global  MHRW    OG     24345916.0   0.000000e+00
# 11      SF      global  MHRW    RW     26710902.5   0.000000e+00
# 12      SW         avg    OG    RW      8798885.0   0.000000e+00
# 13      SW         avg    OG  MHRW     14582755.0   0.000000e+00
# 14      SW         avg    RW    OG     91201115.0   1.000000e+00
# 15      SW         avg    RW  MHRW     58782621.0   1.000000e+00
# 16      SW         avg  MHRW    OG     85417245.0   1.000000e+00
# 17      SW         avg  MHRW    RW     41217379.0  5.958676e-103
# 18      SW      global    OG    RW            0.0   0.000000e+00
# 19      SW      global    OG  MHRW            0.0   0.000000e+00
# 20      SW      global    RW    OG    100000000.0   1.000000e+00
# 21      SW      global    RW  MHRW     41887184.0   3.572550e-88
# 22      SW      global  MHRW    OG    100000000.0   1.000000e+00
# 23      SW      global  MHRW    RW     58112816.0   1.000000e+00
# 24      ER         avg    OG    RW     17636979.0   0.000000e+00
# 25      ER         avg    OG  MHRW     33619856.0   0.000000e+00
# 26      ER         avg    RW    OG     82363021.0   1.000000e+00
# 27      ER         avg    RW  MHRW     65597286.0   1.000000e+00
# 28      ER         avg  MHRW    OG     66380144.0   1.000000e+00
# 29      ER         avg  MHRW    RW     34402714.0   0.000000e+00
# 30      ER      global    OG    RW      4155023.0   0.000000e+00
# 31      ER      global    OG  MHRW     11315215.0   0.000000e+00
# 32      ER      global    RW    OG     95844977.0   1.000000e+00
# 33      ER      global    RW  MHRW     63049999.0   1.000000e+00
# 34      ER      global  MHRW    OG     88684785.0   1.000000e+00
# 35      ER      global  MHRW    RW     36950001.0  1.669735e-224
#
#            Hypothesis
# 0         algo1>alog2
# 1   same distribution
# 2   same distribution
# 3   same distribution
# 4         algo1>alog2
# 5         algo1>alog2
# 6   same distribution
# 7   same distribution
# 8         algo1>alog2
# 9   same distribution
# 10        algo1>alog2
# 11        algo1>alog2
# 12        algo1>alog2
# 13        algo1>alog2
# 14  same distribution
# 15  same distribution
# 16  same distribution
# 17        algo1>alog2
# 18        algo1>alog2
# 19        algo1>alog2
# 20  same distribution
# 21        algo1>alog2
# 22  same distribution
# 23  same distribution
# 24        algo1>alog2
# 25        algo1>alog2
# 26  same distribution
# 27  same distribution
# 28  same distribution
# 29        algo1>alog2
# 30        algo1>alog2
# 31        algo1>alog2
# 32  same distribution
# 33  same distribution
# 34  same distribution
# 35        algo1>alog2

# %% [markdown]
# ## Disease Characterstics

# %%
directory = 'results'
disease_df =  pd.DataFrame()
for network in ['ER','SF','SW']:
    if network == 'ER':
        master_df = pd.DataFrame()
        for idx in range(1,4,1):
            for algo in ['OG','RW','MHRW']:
                # df = pickle.load(open(f"/home/neha/{directory}/{network}_{idx}_{algo}_SIR_agg.pkl","rb"))
                df = pickle.load(open(f"/home/neha/{directory}/{network}/{network}_{idx}_{algo}_SIR_agg.pkl","rb"))
                # df['scaler'] = df['sample_size']
                if algo != 'OG' : df['scaler'] = 500
                else : df['scaler'] = 10000
                df['node_idx'] = df['node_idx']/df['scaler']
                master_df = pd.concat([master_df,df],axis=0)
        master_df['network'] = network
    else:
        master_df = pd.DataFrame()
        for algo in ['OG','RW','MHRW']:
            # df = pickle.load(open(f"/home/neha/{directory}/{network}_combined_{algo}_SIR_agg.pkl","rb"))
            df = pickle.load(open(f"/home/neha/{directory}/{network}/{network}_combined_{algo}_SIR_agg.pkl","rb"))
            if algo != 'OG' : df['scaler'] = 500
            else : df['scaler'] = 10000
            df['node_idx'] = df['node_idx']/df['scaler']
            master_df = pd.concat([master_df,df],axis=0)
        master_df['network'] = network
    disease_df = pd.concat([disease_df,master_df],axis=0)

# %%
disease_df.head()
# Out:
#    beta  net_idx  node_idx  second_inf  inf_time algo  walk_idx  scaler  \
# 0   0.0        0      0.01         0.0       0.0   OG        -1   10000
# 1   0.0        1      0.01         0.0       0.0   OG        -1   10000
# 2   0.0        2      0.01         0.0       0.0   OG        -1   10000
# 3   0.0        3      0.01         0.0       0.0   OG        -1   10000
# 4   0.0        4      0.01         0.0       0.0   OG        -1   10000
#
#   network
# 0      ER
# 1      ER
# 2      ER
# 3      ER
# 4      ER

# %% [markdown]
# ### Normality check

# %%
norm_dis_df = []
for network in ['ER','SF','SW']:
    for algo in ['OG','RW','MHRW']:
        sub_df = disease_df[(disease_df['network']==network) & (disease_df['algo']==algo)]
        for col in ['node_idx','second_inf','inf_time']:
            test_stat = stats.ks_1samp(sub_df[col],stats.norm.cdf)
            norm_dis_df.append([network,algo,col,test_stat.pvalue, test_stat.statistic])
norm_dis_df = pd.DataFrame(norm_dis_df,columns = ['network','algo','col','p_value','ks_stats'])
norm_dis_df['Hypothesis'] = norm_dis_df['p_value'].apply(lambda x : 'Normal' if x >0.05 else 'Not Normal')

# %%
norm_dis_df
# Out:
#    network  algo         col  p_value  ks_stats  Hypothesis
# 0       ER    OG    node_idx      0.0  0.504005  Not Normal
# 1       ER    OG  second_inf      0.0  0.577882  Not Normal
# 2       ER    OG    inf_time      0.0  0.729283  Not Normal
# 3       ER    RW    node_idx      0.0  0.500979  Not Normal
# 4       ER    RW  second_inf      0.0  0.599776  Not Normal
# 5       ER    RW    inf_time      0.0  0.722369  Not Normal
# 6       ER  MHRW    node_idx      0.0  0.501144  Not Normal
# 7       ER  MHRW  second_inf      0.0  0.582140  Not Normal
# 8       ER  MHRW    inf_time      0.0  0.726433  Not Normal
# 9       SF    OG    node_idx      0.0  0.503989  Not Normal
# 10      SF    OG  second_inf      0.0  0.500000  Not Normal
# 11      SF    OG    inf_time      0.0  0.500000  Not Normal
# 12      SF    RW    node_idx      0.0  0.501901  Not Normal
# 13      SF    RW  second_inf      0.0  0.500000  Not Normal
# 14      SF    RW    inf_time      0.0  0.500000  Not Normal
# 15      SF  MHRW    node_idx      0.0  0.506949  Not Normal
# 16      SF  MHRW  second_inf      0.0  0.500000  Not Normal
# 17      SF  MHRW    inf_time      0.0  0.500000  Not Normal
# 18      SW    OG    node_idx      0.0  0.503989  Not Normal
# 19      SW    OG  second_inf      0.0  0.508918  Not Normal
# 20      SW    OG    inf_time      0.0  0.658911  Not Normal
# 21      SW    RW    node_idx      0.0  0.501092  Not Normal
# 22      SW    RW  second_inf      0.0  0.500000  Not Normal
# 23      SW    RW    inf_time      0.0  0.664096  Not Normal
# 24      SW  MHRW    node_idx      0.0  0.501235  Not Normal
# 25      SW  MHRW  second_inf      0.0  0.500000  Not Normal
# 26      SW  MHRW    inf_time      0.0  0.665426  Not Normal

# %% [markdown]
# ### Two tail test

# %%
two_tail_dis_df = []
for network in ['ER','SF','SW']:
    sub_df = disease_df[(disease_df['network']==network)]
    for col in ['node_idx','second_inf','inf_time']:
        for algo1 in ['OG','RW','MHRW']:
            for algo2 in ['OG','RW','MHRW']:
                if algo1 != algo2:
                    U1, p = stats.mannwhitneyu(sub_df[sub_df['algo']==algo1][col],
                                                sub_df[sub_df['algo']==algo2][col]
                                               , method="asymptotic") 
                    # print(algo1,algo2, U1, p)
                    two_tail_dis_df.append([network,col,algo1,algo2, U1, p])
two_tail_dis_df = pd.DataFrame(two_tail_dis_df,columns = ['network','col','algo1','algo2','manwhit_stats','p_value'])
two_tail_dis_df['Hypothesis'] = two_tail_dis_df['p_value'].apply(lambda x : 'same distribution' if x >0.05 else 'diff distribution')

# %%
two_tail_dis_df
# Out:
#    network         col algo1 algo2  manwhit_stats       p_value  \
# 0       ER    node_idx    OG    RW   5.112668e+11  0.000000e+00
# 1       ER    node_idx    OG  MHRW   5.377146e+11  0.000000e+00
# 2       ER    node_idx    RW    OG   6.957746e+11  0.000000e+00
# 3       ER    node_idx    RW  MHRW   6.312105e+13  0.000000e+00
# 4       ER    node_idx  MHRW    OG   6.650506e+11  0.000000e+00
# 5       ER    node_idx  MHRW    RW   5.686137e+13  0.000000e+00
# 6       ER  second_inf    OG    RW   2.525085e+11  0.000000e+00
# 7       ER  second_inf    OG  MHRW   3.329692e+11  0.000000e+00
# 8       ER  second_inf    RW    OG   9.545329e+11  0.000000e+00
# 9       ER  second_inf    RW  MHRW   7.969545e+13  0.000000e+00
# 10      ER  second_inf  MHRW    OG   8.697960e+11  0.000000e+00
# 11      ER  second_inf  MHRW    RW   4.028697e+13  0.000000e+00
# 12      ER    inf_time    OG    RW   6.209532e+11  2.754114e-61
# 13      ER    inf_time    OG  MHRW   6.084394e+11  1.942588e-11
# 14      ER    inf_time    RW    OG   5.860881e+11  2.754114e-61
# 15      ER    inf_time    RW  MHRW   5.898753e+13  0.000000e+00
# 16      ER    inf_time  MHRW    OG   5.943257e+11  1.942588e-11
# 17      ER    inf_time  MHRW    RW   6.099489e+13  0.000000e+00
# 18      SF    node_idx    OG    RW   5.715471e+10  0.000000e+00
# 19      SF    node_idx    OG  MHRW   7.829234e+09  0.000000e+00
# 20      SF    node_idx    RW    OG   1.794643e+11  0.000000e+00
# 21      SF    node_idx    RW  MHRW   9.359686e+11  0.000000e+00
# 22      SF    node_idx  MHRW    OG   1.277844e+11  0.000000e+00
# 23      SF    node_idx  MHRW    RW   1.715995e+12  0.000000e+00
# 24      SF  second_inf    OG    RW   8.454407e+10  0.000000e+00
# 25      SF  second_inf    OG  MHRW   5.994759e+10  0.000000e+00
# 26      SF  second_inf    RW    OG   1.520750e+11  0.000000e+00
# 27      SF  second_inf    RW  MHRW   1.488497e+12  0.000000e+00
# 28      SF  second_inf  MHRW    OG   7.566602e+10  0.000000e+00
# 29      SF  second_inf  MHRW    RW   1.163466e+12  0.000000e+00
# 30      SF    inf_time    OG    RW   1.204087e+11  8.781195e-24
# 31      SF    inf_time    OG  MHRW   7.347720e+10  0.000000e+00
# 32      SF    inf_time    RW    OG   1.162103e+11  8.781195e-24
# 33      SF    inf_time    RW  MHRW   1.376860e+12  0.000000e+00
# 34      SF    inf_time  MHRW    OG   6.213641e+10  0.000000e+00
# 35      SF    inf_time  MHRW    RW   1.275104e+12  0.000000e+00
# 36      SW    node_idx    OG    RW   5.817300e+11  3.519172e-80
# 37      SW    node_idx    OG  MHRW   5.855806e+11  2.798073e-37
# 38      SW    node_idx    RW    OG   6.216510e+11  3.519172e-80
# 39      SW    node_idx    RW  MHRW   6.027751e+13  0.000000e+00
# 40      SW    node_idx  MHRW    OG   6.123194e+11  2.798073e-37
# 41      SW    node_idx  MHRW    RW   5.885722e+13  0.000000e+00
# 42      SW  second_inf    OG    RW   3.912303e+11  0.000000e+00
# 43      SW  second_inf    OG  MHRW   4.510547e+11  0.000000e+00
# 44      SW  second_inf    RW    OG   8.121508e+11  0.000000e+00
# 45      SW  second_inf    RW  MHRW   6.713650e+13  0.000000e+00
# 46      SW  second_inf  MHRW    OG   7.468453e+11  0.000000e+00
# 47      SW  second_inf  MHRW    RW   5.199823e+13  0.000000e+00
# 48      SW    inf_time    OG    RW   6.095186e+11  9.950813e-14
# 49      SW    inf_time    OG  MHRW   6.039315e+11  1.958398e-06
# 50      SW    inf_time    RW    OG   5.938625e+11  9.950813e-14
# 51      SW    inf_time    RW  MHRW   5.929398e+13  4.333100e-77
# 52      SW    inf_time  MHRW    OG   5.939685e+11  1.958398e-06
# 53      SW    inf_time  MHRW    RW   5.984074e+13  4.333100e-77
#
#            Hypothesis
# 0   diff distribution
# 1   diff distribution
# 2   diff distribution
# 3   diff distribution
# 4   diff distribution
# 5   diff distribution
# 6   diff distribution
# 7   diff distribution
# 8   diff distribution
# 9   diff distribution
# 10  diff distribution
# 11  diff distribution
# 12  diff distribution
# 13  diff distribution
# 14  diff distribution
# 15  diff distribution
# 16  diff distribution
# 17  diff distribution
# 18  diff distribution
# 19  diff distribution
# 20  diff distribution
# 21  diff distribution
# 22  diff distribution
# 23  diff distribution
# 24  diff distribution
# 25  diff distribution
# 26  diff distribution
# 27  diff distribution
# 28  diff distribution
# 29  diff distribution
# 30  diff distribution
# 31  diff distribution
# 32  diff distribution
# 33  diff distribution
# 34  diff distribution
# 35  diff distribution
# 36  diff distribution
# 37  diff distribution
# 38  diff distribution
# 39  diff distribution
# 40  diff distribution
# 41  diff distribution
# 42  diff distribution
# 43  diff distribution
# 44  diff distribution
# 45  diff distribution
# 46  diff distribution
# 47  diff distribution
# 48  diff distribution
# 49  diff distribution
# 50  diff distribution
# 51  diff distribution
# 52  diff distribution
# 53  diff distribution

# %% [markdown]
# ### One tail test

# %%
one_tail_dis_df = []
for network in ['ER','SF','SW']:
    sub_df = disease_df[(disease_df['network']==network)]
    for col in ['node_idx','second_inf','inf_time']:
        for algo1 in ['OG','RW','MHRW']:
            for algo2 in ['OG','RW','MHRW']:
                if algo1 != algo2:
                    U1, p = stats.mannwhitneyu(sub_df[sub_df['algo']==algo1][col],
                                                sub_df[sub_df['algo']==algo2][col]
                                               , method="asymptotic", alternative = 'less') 
                    # print(algo1,algo2, U1, p)
                    one_tail_dis_df.append([network,col,algo1,algo2, U1, p])
one_tail_dis_df = pd.DataFrame(one_tail_dis_df,columns = ['network','col','algo1','algo2','manwhit_stats','p_value'])
one_tail_dis_df['Hypothesis'] = one_tail_dis_df['p_value'].apply(lambda x : 'same distribution' if x > 0.05 else 'algo1<algo2')

# %%
one_tail_dis_df
# Out:
#    network         col algo1 algo2  manwhit_stats        p_value  \
# 0       ER    node_idx    OG    RW   5.072729e+11   0.000000e+00
# 1       ER    node_idx    OG  MHRW   6.106545e+11   1.000000e+00
# 2       ER    node_idx    RW    OG   6.997685e+11   1.000000e+00
# 3       ER    node_idx    RW  MHRW   6.946934e+13   1.000000e+00
# 4       ER    node_idx  MHRW    OG   5.921107e+11   6.105959e-19
# 5       ER    node_idx  MHRW    RW   5.051309e+13   0.000000e+00
# 6       ER  second_inf    OG    RW   2.560890e+11   0.000000e+00
# 7       ER  second_inf    OG  MHRW   6.392356e+11   1.000000e+00
# 8       ER  second_inf    RW    OG   9.509523e+11   1.000000e+00
# 9       ER  second_inf    RW  MHRW   9.217288e+13   1.000000e+00
# 10      ER  second_inf  MHRW    OG   5.635296e+11  4.400402e-284
# 11      ER  second_inf  MHRW    RW   2.780954e+13   0.000000e+00
# 12      ER    inf_time    OG    RW   6.205976e+11   1.000000e+00
# 13      ER    inf_time    OG  MHRW   5.984969e+11   3.035255e-03
# 14      ER    inf_time    RW    OG   5.864437e+11   3.466757e-59
# 15      ER    inf_time    RW  MHRW   5.809728e+13   0.000000e+00
# 16      ER    inf_time  MHRW    OG   6.042683e+11   9.969647e-01
# 17      ER    inf_time  MHRW    RW   6.188514e+13   1.000000e+00
# 18      SF    node_idx    OG    RW   6.138715e+10   0.000000e+00
# 19      SF    node_idx    OG  MHRW   2.823753e+10   0.000000e+00
# 20      SF    node_idx    RW    OG   1.752319e+11   1.000000e+00
# 21      SF    node_idx    RW  MHRW   1.209248e+12   0.000000e+00
# 22      SF    node_idx  MHRW    OG   1.073761e+11   1.000000e+00
# 23      SF    node_idx  MHRW    RW   1.442716e+12   1.000000e+00
# 24      SF  second_inf    OG    RW   8.227240e+10   0.000000e+00
# 25      SF  second_inf    OG  MHRW   6.937809e+10   1.000000e+00
# 26      SF  second_inf    RW    OG   1.543466e+11   1.000000e+00
# 27      SF  second_inf    RW  MHRW   1.782846e+12   1.000000e+00
# 28      SF  second_inf  MHRW    OG   6.623552e+10   3.107181e-39
# 29      SF  second_inf  MHRW    RW   8.691172e+11   0.000000e+00
# 30      SF    inf_time    OG    RW   1.257781e+11   1.000000e+00
# 31      SF    inf_time    OG  MHRW   7.372254e+10   1.000000e+00
# 32      SF    inf_time    RW    OG   1.108409e+11  1.498661e-280
# 33      SF    inf_time    RW  MHRW   1.339635e+12   1.000000e+00
# 34      SF    inf_time  MHRW    OG   6.189107e+10   0.000000e+00
# 35      SF    inf_time  MHRW    RW   1.312328e+12   5.010699e-58
# 36      SW    node_idx    OG    RW   5.838616e+11   1.182884e-64
# 37      SW    node_idx    OG  MHRW   6.056249e+11   1.000000e+00
# 38      SW    node_idx    RW    OG   6.195195e+11   1.000000e+00
# 39      SW    node_idx    RW  MHRW   6.180619e+13   1.000000e+00
# 40      SW    node_idx  MHRW    OG   5.922751e+11   9.440309e-11
# 41      SW    node_idx  MHRW    RW   5.732854e+13   0.000000e+00
# 42      SW  second_inf    OG    RW   3.987621e+11   0.000000e+00
# 43      SW  second_inf    OG  MHRW   5.973810e+11   6.693329e-02
# 44      SW  second_inf    RW    OG   8.046190e+11   1.000000e+00
# 45      SW  second_inf    RW  MHRW   7.630930e+13   1.000000e+00
# 46      SW  second_inf  MHRW    OG   6.005190e+11   9.330667e-01
# 47      SW  second_inf  MHRW    RW   4.282543e+13   0.000000e+00
# 48      SW    inf_time    OG    RW   6.103986e+11   1.000000e+00
# 49      SW    inf_time    OG  MHRW   6.033262e+11   9.999854e-01
# 50      SW    inf_time    RW    OG   5.929825e+11   6.255585e-17
# 51      SW    inf_time    RW  MHRW   5.914312e+13  3.426957e-183
# 52      SW    inf_time  MHRW    OG   5.945738e+11   1.460641e-05
# 53      SW    inf_time  MHRW    RW   5.999161e+13   1.000000e+00
#
#            Hypothesis
# 0         algo1<algo2
# 1   same distribution
# 2   same distribution
# 3   same distribution
# 4         algo1<algo2
# 5         algo1<algo2
# 6         algo1<algo2
# 7   same distribution
# 8   same distribution
# 9   same distribution
# 10        algo1<algo2
# 11        algo1<algo2
# 12  same distribution
# 13        algo1<algo2
# 14        algo1<algo2
# 15        algo1<algo2
# 16  same distribution
# 17  same distribution
# 18        algo1<algo2
# 19        algo1<algo2
# 20  same distribution
# 21        algo1<algo2
# 22  same distribution
# 23  same distribution
# 24        algo1<algo2
# 25  same distribution
# 26  same distribution
# 27  same distribution
# 28        algo1<algo2
# 29        algo1<algo2
# 30  same distribution
# 31  same distribution
# 32        algo1<algo2
# 33  same distribution
# 34        algo1<algo2
# 35        algo1<algo2
# 36        algo1<algo2
# 37  same distribution
# 38  same distribution
# 39  same distribution
# 40        algo1<algo2
# 41        algo1<algo2
# 42        algo1<algo2
# 43  same distribution
# 44  same distribution
# 45  same distribution
# 46  same distribution
# 47        algo1<algo2
# 48  same distribution
# 49  same distribution
# 50        algo1<algo2
# 51        algo1<algo2
# 52        algo1<algo2
# 53  same distribution
